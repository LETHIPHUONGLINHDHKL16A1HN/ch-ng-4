# %%
import pandas as pd

# %%
datavn_raw=pd.read_exceḷ('./data19_21.xlsx')
print(datavn_raw)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\python nâng cao\chương 4\vd4.7.12.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/python%20n%C3%A2ng%20cao/ch%C6%B0%C6%A1ng%204/vd4.7.12.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> datavn_raw=pd.read_exceḷ('./data19_21.xlsx')
#       <a href='vscode-notebook-cell:/d%3A/python%20n%C3%A2ng%20cao/ch%C6%B0%C6%A1ng%204/vd4.7.12.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> print(datavn_raw)
#
# AttributeError: module 'pandas' has no attribute 'read_exceḷ'
